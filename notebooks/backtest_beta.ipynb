# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

# Add project root to system path to allow importing modules
sys.path.append(os.path.abspath('..'))

from backtest.engine import BacktestEngine

# %%
# Load the prepared datasets
df = pd.read_parquet('../data/final_dataset.parquet')
bench_df = pd.read_parquet('../data/benchmark_csi300_monthly.parquet')

print(f"Data Loaded. Shape: {df.shape}")
# Out:
# Data Loaded. Shape: (381568, 34)

# %%
FACTOR_NAME = 'beta'  # This will be replaced by the script
print(f"Analyzing Factor: {FACTOR_NAME}")

# Initialize Engine with Benchmark
engine = BacktestEngine(df, factor_name=FACTOR_NAME, benchmark_df=bench_df)
# Out:
# Analyzing Factor: beta

# %%
# Run analysis using Value-Weighted sorting (Academic Standard)
summary = engine.run_analysis(weighting='vw')

# Display Key Metrics
print("Performance Summary:")
for k, v in summary.items():
    print(f"{k}: {v:.4f}")
# Out:
# 正在运行因子分析：beta...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Run analysis using Value-Weighted sorting (Academic Standard)
# ----> 2 summary = engine.run_analysis(weighting='vw')
#       4 # Display Key Metrics
#       5 print("Performance Summary:")
#
# File ~/Documents/Undergrad_Resources/资产管理与投资策略分析/AMQI/backtest/engine.py:115, in BacktestEngine.run_analysis(self, weighting)
#     112 self.results['ic'] = ic_metrics
#     114 # 2. Portfolio Sorting
# --> 115 sort_metrics = self.analyzer.calc_factor_returns(weighting=weighting)
#     116 self.results['sorting'] = sort_metrics
#     118 # 3. Turnover (Q5)
#
# File ~/Documents/Undergrad_Resources/资产管理与投资策略分析/AMQI/backtest/analyzer.py:147, in FactorAnalyzer.calc_factor_returns(self, weighting, quantiles)
#     144     except Exception:
#     145         return np.nan
# --> 147 quintile_rets = self.df.groupby(['trade_date', 'quantile']).apply(w_avg).unstack()
#     149 # 3. Long-Short Return
#     150 # Q5 - Q1
#     151 # Check if we have Q1 and Q5
#     152 if 1.0 in quintile_rets.columns and float(quantiles) in quintile_rets.columns:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:9928, in DataFrame.unstack(self, level, fill_value, sort)
#    9864 """
#    9865 Pivot a level of the (necessarily hierarchical) index labels.
#    9866
#    (...)
#    9924 dtype: float64
#    9925 """
#    9926 from pandas.core.reshape.reshape import unstack
# -> 9928 result = unstack(self, level, fill_value, sort)
#    9930 return result.__finalize__(self, method="unstack")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/reshape.py:504, in unstack(obj, level, fill_value, sort)
#     502 if isinstance(obj, DataFrame):
#     503     if isinstance(obj.index, MultiIndex):
# --> 504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
#     506         return obj.T.stack(future_stack=True)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/reshape.py:534, in _unstack_frame(obj, level, fill_value, sort)
#     529 unstacker = _Unstacker(
#     530     obj.index, level=level, constructor=obj._constructor, sort=sort
#     531 )
#     533 if not obj._can_fast_transpose:
# --> 534     mgr = obj._mgr.unstack(unstacker, fill_value=fill_value)
#     535     return obj._constructor_from_mgr(mgr, axes=mgr.axes)
#     536 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:1596, in BlockManager.unstack(self, unstacker, fill_value)
#    1593 mgr_locs = blk.mgr_locs
#    1594 new_placement = mgr_locs.tile_for_unstack(factor)
# -> 1596 blocks, mask = blk._unstack(
#    1597     unstacker,
#    1598     fill_value,
#    1599     new_placement=new_placement,
#    1600     needs_masking=needs_masking,
#    1601 )
#    1603 new_blocks.extend(blocks)
#    1604 columns_mask.extend(mask)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/internals/blocks.py:1353, in Block._unstack(self, unstacker, fill_value, new_placement, needs_masking)
#    1327 def _unstack(
#    1328     self,
#    1329     unstacker,
#    (...)
#    1332     needs_masking: npt.NDArray[np.bool_],
#    1333 ):
#    1334     """
#    1335     Return a list of unstacked blocks of self
#    1336
#    (...)
#    1351         The mask of columns of `blocks` we should keep.
#    1352     """
# -> 1353     new_values, mask = unstacker.get_new_values(
#    1354         self.values.T, fill_value=fill_value
#    1355     )
#    1357     mask = mask.any(0)
#    1358     # TODO: in all tests we have mask.all(); can we rely on that?
#    1359
#    1360     # Note: these next two lines ensure that
#    1361     #  mask.sum() == sum(len(nb.mgr_locs) for nb in blocks)
#    1362     #  which the calling function needs in order to pass verify_integrity=False
#    1363     #  to the BlockManager constructor
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/reshape.py:278, in _Unstacker.get_new_values(self, values, fill_value)
#     276 if mask_all:
#     277     dtype = values.dtype
# --> 278     new_values = np.empty(result_shape, dtype=dtype)
#     279 else:
#     280     if isinstance(dtype, ExtensionDtype):
#     281         # GH#41875
#     282         # We are assuming that fill_value can be held by this dtype,
#     283         #  unlike the non-EA case that promotes.
#
# TypeError: Cannot interpret 'period[M]' as a data type

# %%
# Plot cumulative returns and IC series
engine.plot_results()
plt.show()
