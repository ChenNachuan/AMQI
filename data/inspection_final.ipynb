# %%
import pandas as pd
import numpy as np
import os
import sys

df_final = pd.read_parquet("final_dataset.parquet")
display(df_final)
# Out:
#                            ret          size           Bm          Ep  \
# trade_date ts_code
# 2000-01-21 000518.SZ       NaN  7.837305e+04          NaN         NaN
# 2000-01-27 000024.SZ       NaN  4.312788e+05          NaN         NaN
#            000601.SZ       NaN  2.830323e+05          NaN  446.388613
#            600707.SH       NaN  4.802400e+05          NaN         NaN
# 2000-01-28 000001.SZ       NaN  2.870917e+06          NaN         NaN
# ...                        ...           ...          ...         ...
# 2025-09-30 920839.BJ -0.025748  5.007030e+05  1187.740885  134.454664
#            920946.BJ -0.112450  4.717448e+05  2548.242595  143.976314
#            920953.BJ -0.084261  4.427689e+05  1242.131550   40.607611
#            920978.BJ  0.672414  6.974745e+05  1012.090858  122.229456
#            920982.BJ -0.127961  3.240125e+06   543.612144  121.000872
#
#                        OCFtoNI  FATurnover  IntCoverage   TaxRate  OpAssetChg  \
# trade_date ts_code
# ...
